# %% [markdown]
# Given the event log from the exercise:
#
# ![Aufgabe_3_log.png](attachment:grafik.png)
#
# Programm a **work distribution** in python (no PM4Py!).
# The work distribution indicates which activities a user has executed and how of-ten they have been executed.
# The result should contain the users on one side and the activities on the other side.
# User and activity should be connected by an edge, if the user executes the activity,
# the frequency of execution should be an-notated as well.
#
#
# - First Step: Represent the log in a suitable format. Create a log with cases.
#     Each case should indicate the relation between activity and user

# %% [markdown]
# - Count the activities per user. You can use a dictionary for this.
# - The dictionary saves all user in the log as well as the activity and their count. It can have the following structure:
#
# <center><b>UA: {'John': {'A': 2, 'C': 1, 'B': 1}, 'Mike': {'B': 1, 'C': 1}, ...}</b></center>

# %% [markdown]
# - Create a graph from the calculated work distribution and visualize it. We recommend to use **Graphviz** for this.

# %%
import graphviz

graph = graphviz.Digraph() # or graphviz.AGraph()

# examples to add nodes and edges:
# graph.node(user, user)
# graph.node(activity, activity)
# graph.edge(user, activity, label=str(count)) or graph.add_edge(user, activity, label=str(count))

#dot.render('work_distribution', format='png', view=True) or graph.draw("distribution.png", prog="dot")
