# %% [markdown]
# # Process Mining - Exercise Sheet 2
#
# 1.	Read the log, paying particular attention to the format of the timestamps. (3P)
# 2.	Write a function that calculate for each transition (transition between two activities):
#  *	  the maximum transition time (9P),
#  *    the minimal transition time (9P),
#  *    the average transition time (9P).

# %% [markdown]
# ## 1. Read the log, paying particular attention to the format of the timestamps. (3P)

# %%
import datetime
with open('ProcessMiningSampleLog.csv', 'r') as f:
    next(f)
    # variable to group instances
    log = dict()

    for line in f:
        # TODO 
        
        
    f.close()

# %% [markdown]
# # 2. Write a function that calculate for each transition (transition between two activities):
# Create the transition matrix:

# %%
Min_D = dict()
Max_D = dict()
Avg_D = dict()
for caseid in log:
     for i in range(0, len(log[caseid])-1):
            # TODO

# %% [markdown]
# * the maximum transition time (9P)

# %%
# Min_D
for ai in sorted(Min_D.keys()):
    for aj in sorted(Min_D[ai].keys()):
        min_td = datetime.timedelta(days=365)
        # TODO
        
        print("Minimum transition time ",ai, '->', aj, ':', min_td)
print("------------------------------------------------------------")

# %% [markdown]
# * the minimal transition time (9P)

# %% [markdown]
# * the average transition time (9P)
