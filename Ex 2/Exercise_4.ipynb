# %% [markdown]
# # Exercise 4

# %%
from pm4py.objects.log.importer.xes import importer as xes_importer
from pm4py.visualization.dfg import visualizer as pt_vis_factory

# %% [markdown]
# ## Load the event log

# %%
log = xes_importer.apply("ProcessMiningSampleLog.xes")

# %% [markdown]
# ## Describe the alpha miner (2P)

# %% [markdown]
# ## Apply the alpha miner (3P)

# %%
from pm4py.algo.discovery.alpha import algorithm as alpha_miner


pt_vis_factory.view(gviz_alpha)

# %% [markdown]
# ## Describe the heuristics miner (2P)

# %% [markdown]
# ## Apply the heuristic miner (3P)
#
# Set the dependency threshold manually

# %%
from pm4py.algo.discovery.heuristics import algorithm as heuristics_miner


pt_vis_factory.view(gviz_heu)

# %% [markdown]
# ## Compute fitness, precision, generalization and simplicity (4P)

# %%
from pm4py.algo.evaluation.replay_fitness import algorithm as replay_fitness_factory


print("Fitness Alpha = ", fitness_alpha)
print("Fitness Heuristic = ", fitness_heu)

# %%
from pm4py.algo.evaluation.precision import algorithm as precision_factory


print("Precision Alpha = ", precision_alpha)
print("Precision Heuristic = ", precision_heuristic)

# %%
from pm4py.algo.evaluation.generalization import algorithm as generalization_factory


print("Generalization Alpha = ", generalization_alpha)
print("Generalization Heuristic = ", generalization_heuristic)

# %%
from pm4py.algo.evaluation.simplicity import algorithm as simplicity_factory


print("Simplicity Alpha=", simplicity_alpha)
print("Simplicity Heuristic = ", simplicity_heuristic)

# %% [markdown]
# ## Interpret the results (6P)
